# %% [markdown]
# <a href="https://colab.research.google.com/github/nlemoff/data102project/blob/main/Checkpoint2DataSourcing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fetch electricity demand data
electricity_url = 'https://api.eia.gov/v2/electricity/retail-sales/data/?frequency=monthly&data[0]=sales&facets[stateid][]=CA'
electricity_response = requests.get(electricity_url, params={'api_key': eia_api_key})

if electricity_response.status_code == 200:
    electricity_data = pd.DataFrame(electricity_response.json()['response']['data'])
    print("Electricity demand data successfully retrieved. Shape:", electricity_data.shape)
    print(electricity_data.head())
else:
    print(f"Error fetching electricity demand data. Status code: {electricity_response.status_code}")
# Out:
# Electricity demand data successfully retrieved. Shape: (1710, 7)
#     period stateid stateDescription sectorid   sectorName        sales  \
# 0  2024-03      CA       California      ALL  all sectors  17659.18439
# 1  2024-03      CA       California      COM   commercial   8749.35296
# 2  2024-03      CA       California      IND   industrial    2927.1454
# 3  2024-03      CA       California      OTH        other         None
# 4  2024-03      CA       California      RES  residential   5918.23144
#
#               sales-units
# 0  million kilowatt hours
# 1  million kilowatt hours
# 2  million kilowatt hours
# 3  million kilowatt hours
# 4  million kilowatt hours

# %%
# Fetch emissions data
emissions_url = 'https://api.eia.gov/v2/electricity/state-electricity-profiles/emissions-by-state-by-fuel/data/?frequency=annual&data[0]=co2-thousand-metric-tons'
emissions_response = requests.get(emissions_url, params={'api_key': eia_api_key})

if emissions_response.status_code == 200:
    emissions_data = pd.DataFrame(emissions_response.json()['response']['data'])
    print("Emissions data successfully retrieved. Shape:", emissions_data.shape)
    print(emissions_data.head())
else:
    print(f"Error fetching emissions data. Status code: {emissions_response.status_code}")
# Out:
# Emissions data successfully retrieved. Shape: (5000, 7)
#   period stateid stateDescription fuelid fuelDescription  \
# 0   2017      AR         Arkansas    PET       Petroleum
# 1   2017      AR         Arkansas    ALL           Total
# 2   1993      AR         Arkansas    COL            Coal
# 3   1993      AR         Arkansas     NG     Natural Gas
# 4   1993      AR         Arkansas    OTH           Other
#
#   co2-thousand-metric-tons co2-thousand-metric-tons-units
# 0                       43           thousand metric tons
# 1                    33322           thousand metric tons
# 2                    18984           thousand metric tons
# 3                     2623           thousand metric tons
# 4                       74           thousand metric tons

# %%
import pandas as pd
import requests

# NOAA API base URL and token
base_url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data"
api_token = "qhmRiNPKavISCVDDZzzxzTxBnWuhOLBp"

# Headers and initial parameters
headers = {"token": api_token}
params = {
    "datasetid": "GHCND",  # Global Historical Climatology Network Daily
    "datatypeid": "TAVG",  # Average temperature
    "locationid": "FIPS:06",  # California
    "startdate": "2023-01-01",  # Start fetching from the start of the year
    "enddate": "2023-12-31",    # End of the year
    "limit": 1000,              # Maximum number of records per request
}

# Initialize an empty DataFrame to store results
temperature_data = pd.DataFrame()

while True:
    # Fetch data
    response = requests.get(base_url, headers=headers, params=params)
    if response.status_code != 200:
        print(f"Error: Received status code {response.status_code}")
        break

    data = response.json()
    results = data.get('results', [])
    if not results:  # If no results, stop fetching
        print("No more data to fetch.")
        break

    # Convert to DataFrame and append to the main dataset
    batch_data = pd.DataFrame(results)
    temperature_data = pd.concat([temperature_data, batch_data], ignore_index=True)

    # Update `startdate` to the day after the latest fetched date
    latest_date = pd.to_datetime(batch_data['date']).max()
    next_start_date = latest_date + pd.Timedelta(days=1)

    # Stop if the latest date exceeds the desired range
    if next_start_date > pd.Timestamp("2023-12-31"):
        print("Data fetching complete.")
        break

    # Update the `startdate` parameter
    params['startdate'] = next_start_date.strftime("%Y-%m-%d")

    print(f"Fetched up to {latest_date}. Continuing from {next_start_date}...")

# Final dataset verification
print("Final dataset shape:", temperature_data.shape)
print(temperature_data.head())
# Out:
# Fetched up to 2023-01-04 00:00:00. Continuing from 2023-01-05 00:00:00...
# Fetched up to 2023-01-08 00:00:00. Continuing from 2023-01-09 00:00:00...
# Fetched up to 2023-01-12 00:00:00. Continuing from 2023-01-13 00:00:00...
# Fetched up to 2023-01-16 00:00:00. Continuing from 2023-01-17 00:00:00...
# Fetched up to 2023-01-20 00:00:00. Continuing from 2023-01-21 00:00:00...
# Fetched up to 2023-01-24 00:00:00. Continuing from 2023-01-25 00:00:00...
# Fetched up to 2023-01-28 00:00:00. Continuing from 2023-01-29 00:00:00...
# Fetched up to 2023-02-01 00:00:00. Continuing from 2023-02-02 00:00:00...
# Fetched up to 2023-02-05 00:00:00. Continuing from 2023-02-06 00:00:00...
# Fetched up to 2023-02-09 00:00:00. Continuing from 2023-02-10 00:00:00...
# Fetched up to 2023-02-13 00:00:00. Continuing from 2023-02-14 00:00:00...
# Fetched up to 2023-02-17 00:00:00. Continuing from 2023-02-18 00:00:00...
# Fetched up to 2023-02-21 00:00:00. Continuing from 2023-02-22 00:00:00...
# Fetched up to 2023-02-25 00:00:00. Continuing from 2023-02-26 00:00:00...
# Fetched up to 2023-03-01 00:00:00. Continuing from 2023-03-02 00:00:00...
# Fetched up to 2023-03-05 00:00:00. Continuing from 2023-03-06 00:00:00...
# Fetched up to 2023-03-09 00:00:00. Continuing from 2023-03-10 00:00:00...
# Fetched up to 2023-03-13 00:00:00. Continuing from 2023-03-14 00:00:00...
# Fetched up to 2023-03-17 00:00:00. Continuing from 2023-03-18 00:00:00...
# Fetched up to 2023-03-21 00:00:00. Continuing from 2023-03-22 00:00:00...
# Fetched up to 2023-03-25 00:00:00. Continuing from 2023-03-26 00:00:00...
# Fetched up to 2023-03-29 00:00:00. Continuing from 2023-03-30 00:00:00...
# Fetched up to 2023-04-02 00:00:00. Continuing from 2023-04-03 00:00:00...
# Fetched up to 2023-04-06 00:00:00. Continuing from 2023-04-07 00:00:00...
# Fetched up to 2023-04-10 00:00:00. Continuing from 2023-04-11 00:00:00...
# Fetched up to 2023-04-14 00:00:00. Continuing from 2023-04-15 00:00:00...
# Fetched up to 2023-04-18 00:00:00. Continuing from 2023-04-19 00:00:00...
# Fetched up to 2023-04-22 00:00:00. Continuing from 2023-04-23 00:00:00...
# Fetched up to 2023-04-26 00:00:00. Continuing from 2023-04-27 00:00:00...
# Fetched up to 2023-04-30 00:00:00. Continuing from 2023-05-01 00:00:00...
# Fetched up to 2023-05-04 00:00:00. Continuing from 2023-05-05 00:00:00...
# Fetched up to 2023-05-08 00:00:00. Continuing from 2023-05-09 00:00:00...
# Fetched up to 2023-05-12 00:00:00. Continuing from 2023-05-13 00:00:00...
# Fetched up to 2023-05-16 00:00:00. Continuing from 2023-05-17 00:00:00...
# Fetched up to 2023-05-20 00:00:00. Continuing from 2023-05-21 00:00:00...
# Fetched up to 2023-05-24 00:00:00. Continuing from 2023-05-25 00:00:00...
# Fetched up to 2023-05-28 00:00:00. Continuing from 2023-05-29 00:00:00...
# Fetched up to 2023-06-01 00:00:00. Continuing from 2023-06-02 00:00:00...
# Fetched up to 2023-06-05 00:00:00. Continuing from 2023-06-06 00:00:00...
# Fetched up to 2023-06-09 00:00:00. Continuing from 2023-06-10 00:00:00...
# Fetched up to 2023-06-13 00:00:00. Continuing from 2023-06-14 00:00:00...
# Fetched up to 2023-06-17 00:00:00. Continuing from 2023-06-18 00:00:00...
# Fetched up to 2023-06-21 00:00:00. Continuing from 2023-06-22 00:00:00...
# Fetched up to 2023-06-25 00:00:00. Continuing from 2023-06-26 00:00:00...
# Fetched up to 2023-06-29 00:00:00. Continuing from 2023-06-30 00:00:00...
# Fetched up to 2023-07-03 00:00:00. Continuing from 2023-07-04 00:00:00...
# Fetched up to 2023-07-07 00:00:00. Continuing from 2023-07-08 00:00:00...
# Fetched up to 2023-07-11 00:00:00. Continuing from 2023-07-12 00:00:00...
# Fetched up to 2023-07-15 00:00:00. Continuing from 2023-07-16 00:00:00...
# Fetched up to 2023-07-19 00:00:00. Continuing from 2023-07-20 00:00:00...
# Fetched up to 2023-07-23 00:00:00. Continuing from 2023-07-24 00:00:00...
# Fetched up to 2023-07-27 00:00:00. Continuing from 2023-07-28 00:00:00...
# Fetched up to 2023-07-31 00:00:00. Continuing from 2023-08-01 00:00:00...
# Fetched up to 2023-08-04 00:00:00. Continuing from 2023-08-05 00:00:00...
# Fetched up to 2023-08-08 00:00:00. Continuing from 2023-08-09 00:00:00...
# Fetched up to 2023-08-12 00:00:00. Continuing from 2023-08-13 00:00:00...
# Fetched up to 2023-08-16 00:00:00. Continuing from 2023-08-17 00:00:00...
# Fetched up to 2023-08-20 00:00:00. Continuing from 2023-08-21 00:00:00...
# Fetched up to 2023-08-24 00:00:00. Continuing from 2023-08-25 00:00:00...
# Error: Received status code 503
# Final dataset shape: (59000, 5)
#                   date datatype            station attributes  value
# 0  2023-01-01T00:00:00     TAVG  GHCND:USR0000CABS       ,,U,     64
# 1  2023-01-01T00:00:00     TAVG  GHCND:USR0000CACT       ,,U,     72
# 2  2023-01-01T00:00:00     TAVG  GHCND:USR0000CALD       ,,U,     28
# 3  2023-01-01T00:00:00     TAVG  GHCND:USR0000CALP       ,,U,     69
# 4  2023-01-01T00:00:00     TAVG  GHCND:USR0000CALT       ,,U,    110

# %%
temperature_data
# Out:
#                       date datatype            station attributes  value
# 0      2023-01-01T00:00:00     TAVG  GHCND:USR0000CABS       ,,U,     64
# 1      2023-01-01T00:00:00     TAVG  GHCND:USR0000CACT       ,,U,     72
# 2      2023-01-01T00:00:00     TAVG  GHCND:USR0000CALD       ,,U,     28
# 3      2023-01-01T00:00:00     TAVG  GHCND:USR0000CALP       ,,U,     69
# 4      2023-01-01T00:00:00     TAVG  GHCND:USR0000CALT       ,,U,    110
# ...                    ...      ...                ...        ...    ...
# 58995  2023-08-24T00:00:00     TAVG  GHCND:USR0000CCLK       ,,U,    246
# 58996  2023-08-24T00:00:00     TAVG  GHCND:USR0000CCLV       ,,U,    224
# 58997  2023-08-24T00:00:00     TAVG  GHCND:USR0000CCMO       ,,U,    198
# 58998  2023-08-24T00:00:00     TAVG  GHCND:USR0000CCOH       ,,U,    288
# 58999  2023-08-24T00:00:00     TAVG  GHCND:USR0000CCOL       ,,U,    187
#
# [59000 rows x 5 columns]

# %%
import pandas as pd
import requests

# NOAA API base URL and token
base_url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data"
api_token = "qhmRiNPKavISCVDDZzzxzTxBnWuhOLBp"

# Headers and parameters
headers = {"token": api_token}
params = {
    "datasetid": "GHCND",  # Global Historical Climatology Network Daily
    "datatypeid": "TAVG",  # Average temperature
    "locationid": "FIPS:06",  # California
    "startdate": "2023-08-25",  # Start fetching from August 25
    "enddate": "2023-12-31",    # End of the year
    "limit": 1000,              # Maximum number of records per request
}

# Initialize an empty DataFrame for new data
new_temperature_data = pd.DataFrame()

while True:
    # Fetch data
    response = requests.get(base_url, headers=headers, params=params)
    if response.status_code != 200:
        print(f"Error: Received status code {response.status_code}")
        break

    data = response.json()
    results = data.get('results', [])
    if not results:  # Stop if no more results
        print("No more data to fetch.")
        break

    # Convert to DataFrame and append to the new dataset
    batch_data = pd.DataFrame(results)
    new_temperature_data = pd.concat([new_temperature_data, batch_data], ignore_index=True)

    # Update `startdate` to the day after the latest fetched date
    latest_date = pd.to_datetime(batch_data['date']).max()
    next_start_date = latest_date + pd.Timedelta(days=1)

    # Stop if the latest date exceeds the desired range
    if next_start_date > pd.Timestamp("2023-12-31"):
        print("Data fetching complete.")
        break

    # Update the `startdate` parameter
    params['startdate'] = next_start_date.strftime("%Y-%m-%d")

    print(f"Fetched up to {latest_date}. Continuing from {next_start_date}...")

# Final dataset verification
print("Final dataset shape:", new_temperature_data.shape)
print(new_temperature_data.head())
# Out:
# Fetched up to 2023-08-28 00:00:00. Continuing from 2023-08-29 00:00:00...
# Fetched up to 2023-09-01 00:00:00. Continuing from 2023-09-02 00:00:00...
# Fetched up to 2023-09-05 00:00:00. Continuing from 2023-09-06 00:00:00...
# Fetched up to 2023-09-09 00:00:00. Continuing from 2023-09-10 00:00:00...
# Fetched up to 2023-09-13 00:00:00. Continuing from 2023-09-14 00:00:00...
# Fetched up to 2023-09-17 00:00:00. Continuing from 2023-09-18 00:00:00...
# Fetched up to 2023-09-21 00:00:00. Continuing from 2023-09-22 00:00:00...
# Fetched up to 2023-09-25 00:00:00. Continuing from 2023-09-26 00:00:00...
# Fetched up to 2023-09-29 00:00:00. Continuing from 2023-09-30 00:00:00...
# Fetched up to 2023-10-03 00:00:00. Continuing from 2023-10-04 00:00:00...
# Fetched up to 2023-10-07 00:00:00. Continuing from 2023-10-08 00:00:00...
# Fetched up to 2023-10-11 00:00:00. Continuing from 2023-10-12 00:00:00...
# Fetched up to 2023-10-15 00:00:00. Continuing from 2023-10-16 00:00:00...
# Fetched up to 2023-10-19 00:00:00. Continuing from 2023-10-20 00:00:00...
# Fetched up to 2023-10-23 00:00:00. Continuing from 2023-10-24 00:00:00...
# Fetched up to 2023-10-27 00:00:00. Continuing from 2023-10-28 00:00:00...
# Fetched up to 2023-10-31 00:00:00. Continuing from 2023-11-01 00:00:00...
# Fetched up to 2023-11-04 00:00:00. Continuing from 2023-11-05 00:00:00...
# Fetched up to 2023-11-08 00:00:00. Continuing from 2023-11-09 00:00:00...
# Fetched up to 2023-11-12 00:00:00. Continuing from 2023-11-13 00:00:00...
# Error: Received status code 503
# Final dataset shape: (20000, 5)
#                   date datatype            station attributes  value
# 0  2023-08-25T00:00:00     TAVG  GHCND:USR0000CABS       ,,U,    240
# 1  2023-08-25T00:00:00     TAVG  GHCND:USR0000CACT       ,,U,    233
# 2  2023-08-25T00:00:00     TAVG  GHCND:USR0000CALD       ,,U,    200
# 3  2023-08-25T00:00:00     TAVG  GHCND:USR0000CALP       ,,U,    244
# 4  2023-08-25T00:00:00     TAVG  GHCND:USR0000CALT       ,,U,    200

# %%
new_temperature_data.to_csv('missing.csv', index=False)

# %%
import pandas as pd
import requests

# NOAA API base URL and token
base_url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data"
api_token = "qhmRiNPKavISCVDDZzzxzTxBnWuhOLBp"

# Headers and parameters
headers = {"token": api_token}
params = {
    "datasetid": "GHCND",  # Global Historical Climatology Network Daily
    "datatypeid": "TAVG",  # Average temperature
    "locationid": "FIPS:06",  # California
    "startdate": "2023-11-13",  # Start fetching from November 13
    "enddate": "2023-12-31",    # End of the year
    "limit": 1000,              # Maximum number of records per request
}

# Initialize an empty DataFrame for new data
temperature_data_11_13_onward = pd.DataFrame()

while True:
    # Fetch data
    response = requests.get(base_url, headers=headers, params=params)
    if response.status_code != 200:
        print(f"Error: Received status code {response.status_code}")
        break

    data = response.json()
    results = data.get('results', [])
    if not results:  # Stop if no more results
        print("No more data to fetch.")
        break

    # Convert to DataFrame and append to the new dataset
    batch_data = pd.DataFrame(results)
    temperature_data_11_13_onward = pd.concat([temperature_data_11_13_onward, batch_data], ignore_index=True)

    # Update `startdate` to the day after the latest fetched date
    latest_date = pd.to_datetime(batch_data['date']).max()
    next_start_date = latest_date + pd.Timedelta(days=1)

    # Stop if the latest date exceeds the desired range
    if next_start_date > pd.Timestamp("2023-12-31"):
        print("Data fetching complete.")
        break

    # Update the `startdate` parameter
    params['startdate'] = next_start_date.strftime("%Y-%m-%d")

    print(f"Fetched up to {latest_date}. Continuing from {next_start_date}...")

# Final dataset verification
print("Final dataset shape:", temperature_data_11_13_onward.shape)
print(temperature_data_11_13_onward.head())
# Out:
# Fetched up to 2023-11-16 00:00:00. Continuing from 2023-11-17 00:00:00...
# Fetched up to 2023-11-20 00:00:00. Continuing from 2023-11-21 00:00:00...
# Error: Received status code 503
# Final dataset shape: (2000, 5)
#                   date datatype            station attributes  value
# 0  2023-11-13T00:00:00     TAVG  GHCND:USR0000CABS       ,,U,    118
# 1  2023-11-13T00:00:00     TAVG  GHCND:USR0000CACT       ,,U,    123
# 2  2023-11-13T00:00:00     TAVG  GHCND:USR0000CALD       ,,U,     78
# 3  2023-11-13T00:00:00     TAVG  GHCND:USR0000CALP       ,,U,    157
# 4  2023-11-13T00:00:00     TAVG  GHCND:USR0000CALT       ,,U,    132

# %%
temperature_data_11_13_onward
# Out:
#                      date datatype            station attributes  value
# 0     2023-11-13T00:00:00     TAVG  GHCND:USR0000CABS       ,,U,    118
# 1     2023-11-13T00:00:00     TAVG  GHCND:USR0000CACT       ,,U,    123
# 2     2023-11-13T00:00:00     TAVG  GHCND:USR0000CALD       ,,U,     78
# 3     2023-11-13T00:00:00     TAVG  GHCND:USR0000CALP       ,,U,    157
# 4     2023-11-13T00:00:00     TAVG  GHCND:USR0000CALT       ,,U,    132
# ...                   ...      ...                ...        ...    ...
# 1995  2023-11-20T00:00:00     TAVG  GHCND:USR0000CCLE       ,,U,    149
# 1996  2023-11-20T00:00:00     TAVG  GHCND:USR0000CCLK       ,,U,    164
# 1997  2023-11-20T00:00:00     TAVG  GHCND:USR0000CCLV       ,,U,    114
# 1998  2023-11-20T00:00:00     TAVG  GHCND:USR0000CCMO       ,,U,     98
# 1999  2023-11-20T00:00:00     TAVG  GHCND:USR0000CCOH       ,,U,    137
#
# [2000 rows x 5 columns]

# %%
import pandas as pd
import requests

# NOAA API base URL and token
base_url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data"
api_token = "qhmRiNPKavISCVDDZzzxzTxBnWuhOLBp"

# Headers and parameters
headers = {"token": api_token}
params = {
    "datasetid": "GHCND",  # Global Historical Climatology Network Daily
    "datatypeid": "TAVG",  # Average temperature
    "locationid": "FIPS:06",  # California
    "startdate": "2023-11-21",  # Start fetching from November 21
    "enddate": "2023-12-31",    # End of the year
    "limit": 1000,              # Maximum number of records per request
}

# Initialize an empty DataFrame for new data
temperature_data_11_21_onward = pd.DataFrame()

while True:
    # Fetch data
    response = requests.get(base_url, headers=headers, params=params)
    if response.status_code != 200:
        print(f"Error: Received status code {response.status_code}")
        break

    data = response.json()
    results = data.get('results', [])
    if not results:  # Stop if no more results
        print("No more data to fetch.")
        break

    # Convert to DataFrame and append to the new dataset
    batch_data = pd.DataFrame(results)
    temperature_data_11_21_onward = pd.concat([temperature_data_11_21_onward, batch_data], ignore_index=True)

    # Update `startdate` to the day after the latest fetched date
    latest_date = pd.to_datetime(batch_data['date']).max()
    next_start_date = latest_date + pd.Timedelta(days=1)

    # Stop if the latest date exceeds the desired range
    if next_start_date > pd.Timestamp("2023-12-31"):
        print("Data fetching complete.")
        break

    # Update the `startdate` parameter
    params['startdate'] = next_start_date.strftime("%Y-%m-%d")

    print(f"Fetched up to {latest_date}. Continuing from {next_start_date}...")

# Final dataset verification
print("Final dataset shape:", temperature_data_11_21_onward.shape)
print(temperature_data_11_21_onward.head())
# Out:
# Fetched up to 2023-11-24 00:00:00. Continuing from 2023-11-25 00:00:00...
# Fetched up to 2023-11-28 00:00:00. Continuing from 2023-11-29 00:00:00...
# Fetched up to 2023-12-02 00:00:00. Continuing from 2023-12-03 00:00:00...
# Fetched up to 2023-12-06 00:00:00. Continuing from 2023-12-07 00:00:00...
# Fetched up to 2023-12-10 00:00:00. Continuing from 2023-12-11 00:00:00...
# Fetched up to 2023-12-14 00:00:00. Continuing from 2023-12-15 00:00:00...
# Fetched up to 2023-12-18 00:00:00. Continuing from 2023-12-19 00:00:00...
# Fetched up to 2023-12-22 00:00:00. Continuing from 2023-12-23 00:00:00...
# Fetched up to 2023-12-26 00:00:00. Continuing from 2023-12-27 00:00:00...
# Fetched up to 2023-12-30 00:00:00. Continuing from 2023-12-31 00:00:00...
# Data fetching complete.
# Final dataset shape: (10046, 5)
#                   date datatype            station attributes  value
# 0  2023-11-21T00:00:00     TAVG  GHCND:USR0000CABS       ,,U,    134
# 1  2023-11-21T00:00:00     TAVG  GHCND:USR0000CACT       ,,U,    130
# 2  2023-11-21T00:00:00     TAVG  GHCND:USR0000CALD       ,,U,    106
# 3  2023-11-21T00:00:00     TAVG  GHCND:USR0000CALP       ,,U,    169
# 4  2023-11-21T00:00:00     TAVG  GHCND:USR0000CALT       ,,U,    111

# %%
# Combine all DataFrames into one
all_temperature_data = pd.concat(
    [temperature_data, temperature_data_11_13_onward, temperature_data_11_21_onward],
    ignore_index=True
)

# Ensure chronological order by sorting on the 'date' column
all_temperature_data['date'] = pd.to_datetime(all_temperature_data['date'])  # Ensure 'date' is a datetime type
all_temperature_data = all_temperature_data.sort_values(by='date').reset_index(drop=True)

# Verify combined DataFrame
print("Combined dataset shape:", all_temperature_data.shape)
print(all_temperature_data.head())
print(all_temperature_data.tail())
# Out:
# Combined dataset shape: (71046, 5)
#         date datatype            station attributes  value
# 0 2023-01-01     TAVG  GHCND:USR0000CABS       ,,U,     64
# 1 2023-01-01     TAVG  GHCND:USR0000CSFD       ,,U,    123
# 2 2023-01-01     TAVG  GHCND:USR0000CSEC       ,,U,     45
# 3 2023-01-01     TAVG  GHCND:USR0000CSDD       ,,U,    -54
# 4 2023-01-01     TAVG  GHCND:USR0000CSDC       ,,U,     29
#             date datatype            station attributes  value
# 71041 2023-12-31     TAVG  GHCND:USS0020H06S       ,,T,     -4
# 71042 2023-12-31     TAVG  GHCND:USS0020H12S       ,,T,    -28
# 71043 2023-12-31     TAVG  GHCND:USS0020K03S       ,,T,    -17
# 71044 2023-12-31     TAVG  GHCND:USS0019L39S       ,,T,      3
# 71045 2023-12-31     TAVG  GHCND:USW00093228      H,,S,    122

# %%
# Export the combined dataset to a CSV file
output_file = "temperature_data_2023.csv"
all_temperature_data.to_csv(output_file, index=False)

print(f"Data successfully exported to {output_file}")
# Out:
# Data successfully exported to temperature_data_2023.csv

# %%
# Electricity retail sales data for all sectors
URL = 'https://api.eia.gov/v2/electricity/retail-sales/data/?frequency=monthly&data[0]=sales&facets[stateid][]=CA&facets[sectorid][]=ALL&start=2023-01&end=2024-01&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'
key = 'vgyKsY7pYEHEeo0dncg7ho5nlLp0h2JjAAMBT6nL'
data = requests.get(URL, params={'api_key': key}).json()
state_wise_energy = pd.DataFrame.from_dict(data['response']['data'])

# Save to CSV
state_wise_energy
# Out:
#      period stateid stateDescription sectorid   sectorName        sales  \
# 0   2024-01      CA       California      ALL  all sectors  20040.74935
# 1   2023-12      CA       California      ALL  all sectors  18660.12634
# 2   2023-11      CA       California      ALL  all sectors  18479.20564
# 3   2023-10      CA       California      ALL  all sectors  20390.47299
# 4   2023-09      CA       California      ALL  all sectors  22466.03859
# 5   2023-08      CA       California      ALL  all sectors  25101.55563
# 6   2023-07      CA       California      ALL  all sectors  23048.26218
# 7   2023-06      CA       California      ALL  all sectors  19333.43379
# 8   2023-05      CA       California      ALL  all sectors    18288.412
# 9   2023-04      CA       California      ALL  all sectors  16261.33366
# 10  2023-03      CA       California      ALL  all sectors  19506.41869
# 11  2023-02      CA       California      ALL  all sectors  17440.48579
# 12  2023-01      CA       California      ALL  all sectors  20504.70675
#
#                sales-units
# 0   million kilowatt hours
# 1   million kilowatt hours
# 2   million kilowatt hours
# 3   million kilowatt hours
# 4   million kilowatt hours
# 5   million kilowatt hours
# 6   million kilowatt hours
# 7   million kilowatt hours
# 8   million kilowatt hours
# 9   million kilowatt hours
# 10  million kilowatt hours
# 11  million kilowatt hours
# 12  million kilowatt hours

# %%
# Electricity retail sales data for the residential sector
URL = 'https://api.eia.gov/v2/electricity/retail-sales/data/?frequency=monthly&data[0]=sales&facets[stateid][]=CA&facets[sectorid][]=RES&start=2023-01&end=2024-01&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'
data = requests.get(URL, params={'api_key': key}).json()
state_wise_energy_res = pd.DataFrame.from_dict(data['response']['data'])

# Save to CSV
state_wise_energy_res.to_csv('state_wise_energy_residential.csv', index=False)

# %%
# Electricity retail sales data for the industrial sector
URL = 'https://api.eia.gov/v2/electricity/retail-sales/data/?frequency=monthly&data[0]=sales&facets[stateid][]=CA&facets[sectorid][]=IND&start=2023-01&end=2024-01&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'
data = requests.get(URL, params={'api_key': key}).json()
state_wise_energy_ind = pd.DataFrame.from_dict(data['response']['data'])

# Save to CSV
state_wise_energy_ind.to_csv('state_wise_energy_industrial.csv', index=False)

# %%
# Electricity retail sales data for the transportation sector
URL = 'https://api.eia.gov/v2/electricity/retail-sales/data/?frequency=monthly&data[0]=sales&facets[stateid][]=CA&facets[sectorid][]=TRA&start=2023-01&end=2024-01&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'
data = requests.get(URL, params={'api_key': key}).json()
state_wise_energy_tra = pd.DataFrame.from_dict(data['response']['data'])

# Save to CSV
state_wise_energy_tra
# Out:
#      period stateid stateDescription sectorid      sectorName     sales  \
# 0   2024-01      CA       California      TRA  transportation  51.74829
# 1   2023-12      CA       California      TRA  transportation  51.26901
# 2   2023-11      CA       California      TRA  transportation  58.99317
# 3   2023-10      CA       California      TRA  transportation  62.01097
# 4   2023-09      CA       California      TRA  transportation  60.92997
# 5   2023-08      CA       California      TRA  transportation  68.17682
# 6   2023-07      CA       California      TRA  transportation  62.11936
# 7   2023-06      CA       California      TRA  transportation  62.24481
# 8   2023-05      CA       California      TRA  transportation   71.4942
# 9   2023-04      CA       California      TRA  transportation  56.53867
# 10  2023-03      CA       California      TRA  transportation  61.21789
# 11  2023-02      CA       California      TRA  transportation  56.59785
# 12  2023-01      CA       California      TRA  transportation  53.83829
#
#                sales-units
# 0   million kilowatt hours
# 1   million kilowatt hours
# 2   million kilowatt hours
# 3   million kilowatt hours
# 4   million kilowatt hours
# 5   million kilowatt hours
# 6   million kilowatt hours
# 7   million kilowatt hours
# 8   million kilowatt hours
# 9   million kilowatt hours
# 10  million kilowatt hours
# 11  million kilowatt hours
# 12  million kilowatt hours

# %%
# State-level electricity emissions data
URL = 'https://api.eia.gov/v2/electricity/state-electricity-profiles/emissions-by-state-by-fuel/data/?frequency=annual&data[0]=co2-rate-lbs-mwh&data[1]=co2-thousand-metric-tons&data[2]=nox-rate-lbs-mwh&data[3]=nox-short-tons&data[4]=so2-rate-lbs-mwh&data[5]=so2-short-tons&start=1990&end=2023&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'
data = requests.get(URL, params={'api_key': key}).json()
state_emissions = pd.DataFrame.from_dict(data['response']['data'])

# Save to CSV
state_emissions
# Out:
#      period stateid stateDescription fuelid fuelDescription co2-rate-lbs-mwh  \
# 0      2023      AZ          Arizona    COL            Coal             None
# 1      2023      WY          Wyoming    ALL           Total             1864
# 2      2023      WY          Wyoming    PET       Petroleum             None
# 3      2023      WY          Wyoming    OTH           Other             None
# 4      2023      WY          Wyoming     NG     Natural Gas             None
# ...     ...     ...              ...    ...             ...              ...
# 4995   2004      CA       California    COL            Coal             None
# 4996   2004      AZ          Arizona    ALL           Total             1113
# 4997   2004      AZ          Arizona    PET       Petroleum             None
# 4998   2004      AZ          Arizona    OTH           Other             None
# 4999   2004      AZ          Arizona     NG     Natural Gas             None
#
#      co2-thousand-metric-tons nox-rate-lbs-mwh nox-short-tons  \
# 0                       12863             None           9238
# 1                       36580              1.4          31178
# 2                          37             None             22
# 3                           0             None           3436
# 4                        1516             None           2489
# ...                       ...              ...            ...
# 4995                     3950             None           3455
# 4996                    52900              1.6          86019
# 4997                       40             None             58
# 4998                        0             None            227
# 4999                    13057             None           4823
#
#      so2-rate-lbs-mwh so2-short-tons   co2-rate-lbs-mwh-units  \
# 0                None           6854  pounds per megawatthour
# 1                 1.1          24209  pounds per megawatthour
# 2                None             13  pounds per megawatthour
# 3                None              8  pounds per megawatthour
# 4                None              9  pounds per megawatthour
# ...               ...            ...                      ...
# 4995             None           2740  pounds per megawatthour
# 4996              1.2          60544  pounds per megawatthour
# 4997             None             25  pounds per megawatthour
# 4998             None              0  pounds per megawatthour
# 4999             None             79  pounds per megawatthour
#
#      co2-thousand-metric-tons-units   nox-rate-lbs-mwh-units  \
# 0              thousand metric tons  pounds per megawatthour
# 1              thousand metric tons  pounds per megawatthour
# 2              thousand metric tons  pounds per megawatthour
# 3              thousand metric tons  pounds per megawatthour
# 4              thousand metric tons  pounds per megawatthour
# ...                             ...                      ...
# 4995           thousand metric tons  pounds per megawatthour
# 4996           thousand metric tons  pounds per megawatthour
# 4997           thousand metric tons  pounds per megawatthour
# 4998           thousand metric tons  pounds per megawatthour
# 4999           thousand metric tons  pounds per megawatthour
#
#      nox-short-tons-units   so2-rate-lbs-mwh-units so2-short-tons-units
# 0              short tons  pounds per megawatthour           short tons
# 1              short tons  pounds per megawatthour           short tons
# 2              short tons  pounds per megawatthour           short tons
# 3              short tons  pounds per megawatthour           short tons
# 4              short tons  pounds per megawatthour           short tons
# ...                   ...                      ...                  ...
# 4995           short tons  pounds per megawatthour           short tons
# 4996           short tons  pounds per megawatthour           short tons
# 4997           short tons  pounds per megawatthour           short tons
# 4998           short tons  pounds per megawatthour           short tons
# 4999           short tons  pounds per megawatthour           short tons
#
# [5000 rows x 17 columns]

# %%
state_emissions[(state_emissions['period'] == '2023') & (state_emissions['stateid'] == 'CA')]
# Out:
#     period stateid stateDescription fuelid fuelDescription co2-rate-lbs-mwh  \
# 240   2023      CA       California    ALL           Total              440
# 241   2023      CA       California    PET       Petroleum             None
# 242   2023      CA       California    OTH           Other             None
# 243   2023      CA       California     NG     Natural Gas             None
# 244   2023      CA       California    COL            Coal             None
#
#     co2-thousand-metric-tons nox-rate-lbs-mwh nox-short-tons so2-rate-lbs-mwh  \
# 240                    43360               .6          65559                0
# 241                       68             None            588             None
# 242                      656             None          23494             None
# 243                    41527             None          40742             None
# 244                     1109             None            735             None
#
#     so2-short-tons   co2-rate-lbs-mwh-units co2-thousand-metric-tons-units  \
# 240           1043  pounds per megawatthour           thousand metric tons
# 241             85  pounds per megawatthour           thousand metric tons
# 242            558  pounds per megawatthour           thousand metric tons
# 243            229  pounds per megawatthour           thousand metric tons
# 244            171  pounds per megawatthour           thousand metric tons
#
#       nox-rate-lbs-mwh-units nox-short-tons-units   so2-rate-lbs-mwh-units  \
# 240  pounds per megawatthour           short tons  pounds per megawatthour
# 241  pounds per megawatthour           short tons  pounds per megawatthour
# 242  pounds per megawatthour           short tons  pounds per megawatthour
# 243  pounds per megawatthour           short tons  pounds per megawatthour
# 244  pounds per megawatthour           short tons  pounds per megawatthour
#
#     so2-short-tons-units
# 240           short tons
# 241           short tons
# 242           short tons
# 243           short tons
# 244           short tons

# %%
# Crude oil import data
URL = 'https://api.eia.gov/v2/crude-oil-imports/data/?frequency=monthly&data[0]=quantity&start=2023-01&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'
data = requests.get(URL, params={'api_key': key}).json()
crude_oil = pd.DataFrame.from_dict(data['response']['data'])

# Save to CSV
crude_oil.to_csv('crude_oil_imports.csv', index=False)

# %%
# Electric power operational data
URL = 'https://api.eia.gov/v2/electricity/electric-power-operational-data/data/?frequency=monthly&data[0]=ash-content&data[1]=consumption-for-eg&data[2]=consumption-for-eg-btu&data[3]=consumption-uto&data[4]=consumption-uto-btu&data[5]=cost&data[6]=cost-per-btu&data[7]=generation&data[8]=heat-content&data[9]=receipts&data[10]=receipts-btu&data[11]=stocks&data[12]=sulfur-content&data[13]=total-consumption&data[14]=total-consumption-btu&start=2001-01&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'
data = requests.get(URL, params={'api_key': key}).json()
electricity_power_consumption = pd.DataFrame.from_dict(data['response']['data'])

# Save to CSV
electricity_power_consumption.to_csv('electricity_power_operational_data.csv', index=False)
# Out:
#        period location    stateDescription sectorid sectorDescription  \
# 0     2024-09       NE            Nebraska       99       All Sectors
# 1     2024-09       US          U.S. Total        1  Electric Utility
# 2     2024-09       US          U.S. Total        1  Electric Utility
# 3     2024-09      WNC  West North Central       99       All Sectors
# 4     2024-09      WNC  West North Central       99       All Sectors
# ...       ...      ...                 ...      ...               ...
# 4995  2024-09       NE            Nebraska       99       All Sectors
# 4996  2024-09       NE            Nebraska       99       All Sectors
# 4997  2024-09       NE            Nebraska       99       All Sectors
# 4998  2024-09       NE            Nebraska       99       All Sectors
# 4999  2024-09       NE            Nebraska       99       All Sectors
#
#      fueltypeid                 fuelTypeDescription ash-content  \
# 0           BIO                             biomass        None
# 1           HPS       hydro-electric pumped storage        None
# 2           HYC          conventional hydroelectric        None
# 3           PET                           petroleum        None
# 4            RC                        refined coal         8.5
# ...         ...                                 ...         ...
# 4995        DFO                 distillate fuel oil        None
# 4996        COW                   all coal products        5.33
# 4997        COL          coal, excluding waste coal        5.33
# 4998        BIT                     bituminous coal        None
# 4999        BIS  bituminous coal and synthetic coal        None
#
#      ash-content-units consumption-for-eg  ... receipts-btu  \
# 0              percent            171.037  ...         None
# 1              percent                  0  ...         None
# 2              percent                  0  ...         None
# 3              percent               None  ...    251.53341
# 4              percent           1053.492  ...       72.936
# ...                ...                ...  ...          ...
# 4995           percent               None  ...         None
# 4996           percent            984.884  ...  13288.08831
# 4997           percent            984.884  ...  13288.08831
# 4998           percent                  0  ...         None
# 4999           percent                  0  ...         None
#
#      receipts-btu-units stocks             stocks-units sulfur-content  \
# 0           billion Btu   None  thousand physical units           None
# 1           billion Btu      0  thousand physical units           None
# 2           billion Btu      0  thousand physical units           None
# 3           billion Btu   None         thousand barrels           None
# 4           billion Btu   None      thousand short tons            .65
# ...                 ...    ...                      ...            ...
# 4995        billion Btu   None      thousand short tons           None
# 4996        billion Btu   None      thousand short tons            .29
# 4997        billion Btu   None      thousand short tons            .29
# 4998        billion Btu   None      thousand short tons           None
# 4999        billion Btu   None      thousand short tons           None
#
#      sulfur-content-units total-consumption  total-consumption-units  \
# 0                 percent            173.97  thousand physical units
# 1                 percent                 0  thousand physical units
# 2                 percent                 0  thousand physical units
# 3                 percent              None         thousand barrels
# 4                 percent          1100.837      thousand short tons
# ...                   ...               ...                      ...
# 4995              percent              None      thousand short tons
# 4996              percent          1014.128      thousand short tons
# 4997              percent          1014.128      thousand short tons
# 4998              percent                 0      thousand short tons
# 4999              percent                 0      thousand short tons
#
#      total-consumption-btu total-consumption-btu-units
# 0                   .08889               million MMBtu
# 1                        0               million MMBtu
# 2                 50.83491               million MMBtu
# 3                     None               million MMBtu
# 4                 16.55815               million MMBtu
# ...                    ...                         ...
# 4995                  None               million MMBtu
# 4996              17.56649               million MMBtu
# 4997              17.56649               million MMBtu
# 4998                     0               million MMBtu
# 4999                     0               million MMBtu
#
# [5000 rows x 37 columns]
